# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from radical.entk import Profiler
import radical.analytics as ra
import radical.utils as ru
import radical.pilot as rp
import numpy as np
from math import sqrt
import os

os.environ['RADICAL_PILOT_DBURL'] = 'mongodb://user:user@ds153652.mlab.com:53652/test_08_08'

# %matplotlib inline
# Out:
# /home/vivek/ves/ve_entk/lib/python2.7/site-packages/radical/utils/atfork/stdlib_fixer.py:63: UserWarning: logging module already imported before fixup.
#   warnings.warn('logging module already imported before fixup.')

# %%
# Constants
sleep_times = [1,10,100,1000]
trials=5
data_loc = '../raw_data'
FONTSIZE=18

# %%
# Generate task uids

def get_task_uids(num_tasks):
    
    task_uids = []
    for t in range(num_tasks):
        task_uids.append('radical.entk.task.%04d'%t)

    return task_uids

# %%
df = pd.DataFrame(columns=['EnTK setup + teardown overhead', 'EnTK task management overhead', 'RP overhead'])
df_err = pd.DataFrame(columns=['EnTK setup + teardown overhead', 'EnTK task management overhead', 'RP overhead'])

for sleep in sleep_times:    
    
    entk_setup_teardown_list = list()
    entk_task_overhead_list = list()
    rp_overhead_list = list()
    
    for t in range(1,trials+1):

        json_files = glob.glob('{0}/sleep-{1}-trial-{2}/*.json'.format(data_loc,sleep, t))
        json_file = json_files[0]
        json      = ru.read_json(json_file)
        sid       = os.path.basename(json_file)[:-5]

        session = ra.Session(sid, 'radical.pilot', src='{0}/sleep-{1}-trial-{2}/'.format(data_loc,sleep, t))
        units = session.filter(etype='unit', inplace=False)
    
        p = Profiler(src = '{0}/sleep-{1}-trial-{2}/'.format(data_loc,sleep, t))
        
        task_uids = get_task_uids(16)
        
        entk_dur = p.duration(task_uids, states=['SCHEDULING', 'DONE'])
    
        rp_dur = units.duration([rp.UMGR_SCHEDULING_PENDING, rp.DONE])
        exec_dur = units.duration([rp.AGENT_EXECUTING, rp.AGENT_STAGING_OUTPUT_PENDING])
    
        # Time taken in appmanager to rreq function call
        entk_core_1 = p.duration('radical.entk.appmanager.0000', events=['create amgr obj', 'init rreq submission'])
        
        # Time taken to tear down appmanager
        entk_core_2 = p.duration('radical.entk.appmanager.0000', events=['start termination', 'termination done'])
    
        # Time taken to create resource manager obj
        entk_core_3 = p.duration('radical.entk.resource_manager.0000', events = ['create rmgr obj', 'rmgr obj created'])
    
        # Time taken to create and submit resource reservation
        entk_core_4 = p.duration('radical.entk.resource_manager.0000', events = ['creating rreq', 'rreq submitted'])
    
        # Time taken to deallocate resource reservation
        entk_core_5 = p.duration('radical.entk.resource_manager.0000', events = ['canceling resource allocation', 'resource allocation cancelled'])
    
        # Queue
        queue_time = p.duration('radical.entk.resource_manager.0000', events = ['rreq submitted', 'resource active'])
    
    
        entk_setup_teardown_dur = entk_core_1 + entk_core_2 + entk_core_3 
        entk_task_overhead = entk_dur - rp_dur
        rp_overhead = rp_dur - exec_dur
    
        print 'EnTK setup + teardown overhead: ', entk_setup_teardown_dur
        print 'EnTK task management overhead: ', entk_task_overhead
        print 'RP overhead: ', rp_overhead
        print 'Execution duration: ', sleep
        print 'Trial: ', t
        print '---------------------------------------'
        
        entk_setup_teardown_list.append(entk_setup_teardown_dur)
        entk_task_overhead_list.append(entk_task_overhead)
        rp_overhead_list.append(rp_overhead)
    
    df.loc[sleep] = [np.mean(entk_setup_teardown_list), 
                     np.mean(entk_task_overhead_list), 
                     np.mean(rp_overhead_list)]
    
    df_err.loc[sleep] = [np.std(entk_setup_teardown_list)/sqrt(trials), 
                     np.std(entk_task_overhead_list)/sqrt(trials), 
                     np.std(rp_overhead_list)/sqrt(trials)]
# Out:
# EnTK setup + teardown overhead:  3.53660011292
# EnTK task management overhead:  1.80969977379
# RP overhead:  3.64079999924
# Execution duration:  1
# Trial:  1
# ---------------------------------------
# EnTK setup + teardown overhead:  4.95280003548
# EnTK task management overhead:  10.0983998775
# RP overhead:  4.08069992065
# Execution duration:  1
# Trial:  2
# ---------------------------------------
# EnTK setup + teardown overhead:  13.0934002399
# EnTK task management overhead:  11.8429999352
# RP overhead:  2.49930000305
# Execution duration:  1
# Trial:  3
# ---------------------------------------
# EnTK setup + teardown overhead:  5.34379982948
# EnTK task management overhead:  11.3169000149
# RP overhead:  3.48629999161
# Execution duration:  1
# Trial:  4
# ---------------------------------------
# EnTK setup + teardown overhead:  4.63879990578
# EnTK task management overhead:  10.8943998814
# RP overhead:  2.98740005493
# Execution duration:  1
# Trial:  5
# ---------------------------------------
# EnTK setup + teardown overhead:  6.40589976311
# EnTK task management overhead:  9.42840003967
# RP overhead:  3.44650006294
# Execution duration:  10
# Trial:  1
# ---------------------------------------
# EnTK setup + teardown overhead:  4.10249972343
# EnTK task management overhead:  10.14599967
# RP overhead:  4.16480016708
# Execution duration:  10
# Trial:  2
# ---------------------------------------
# EnTK setup + teardown overhead:  4.85199975967
# EnTK task management overhead:  10.0722000599
# RP overhead:  5.00189995766
# Execution duration:  10
# Trial:  3
# ---------------------------------------
# EnTK setup + teardown overhead:  5.30930018425
# EnTK task management overhead:  10.4395000935
# RP overhead:  3.84630012512
# Execution duration:  10
# Trial:  4
# ---------------------------------------
# EnTK setup + teardown overhead:  7.15869998932
# EnTK task management overhead:  10.2897999287
# RP overhead:  3.89450001717
# Execution duration:  10
# Trial:  5
# ---------------------------------------
# EnTK setup + teardown overhead:  6.85980033875
# EnTK task management overhead:  9.29089999199
# RP overhead:  4.96529984474
# Execution duration:  100
# Trial:  1
# ---------------------------------------
# EnTK setup + teardown overhead:  6.89199972153
# EnTK task management overhead:  9.20179986954
# RP overhead:  4.46760010719
# Execution duration:  100
# Trial:  2
# ---------------------------------------
# EnTK setup + teardown overhead:  7.03679990768
# EnTK task management overhead:  9.23860001564
# RP overhead:  3.79700016975
# Execution duration:  100
# Trial:  3
# ---------------------------------------
# EnTK setup + teardown overhead:  20.1922001839
# EnTK task management overhead:  10.1570999622
# RP overhead:  4.6180999279
# Execution duration:  100
# Trial:  4
# ---------------------------------------
# EnTK setup + teardown overhead:  6.35250020027
# EnTK task management overhead:  9.3490998745
# RP overhead:  4.8640999794
# Execution duration:  100
# Trial:  5
# ---------------------------------------
# EnTK setup + teardown overhead:  6.13750004768
# EnTK task management overhead:  10.8789000511
# RP overhead:  4.0640001297
# Execution duration:  1000
# Trial:  1
# ---------------------------------------
# EnTK setup + teardown overhead:  23.8921999931
# EnTK task management overhead:  10.0896999836
# RP overhead:  4.953799963
# Execution duration:  1000
# Trial:  2
# ---------------------------------------
# EnTK setup + teardown overhead:  6.00989985466
# EnTK task management overhead:  10.4667999744
# RP overhead:  3.5288002491
# Execution duration:  1000
# Trial:  3
# ---------------------------------------
# EnTK setup + teardown overhead:  23.521999836
# EnTK task management overhead:  10.8400001526
# RP overhead:  4.09799981117
# Execution duration:  1000
# Trial:  4
# ---------------------------------------
# EnTK setup + teardown overhead:  6.8616001606
# EnTK task management overhead:  11.0236001015
# RP overhead:  3.00259995461
# Execution duration:  1000
# Trial:  5
# ---------------------------------------

# %%
ax = df.plot(kind='bar', 
             yerr=df_err,
             fontsize=FONTSIZE,
             title=  'Time taken by EnTK and RP to execute a workflow \n'+
                     'Workflow: 1 Pipeline, 1 Stage per Pipeline and 16 Tasks per Stage \n'+
                     'Resource: XSEDE.SuperMIC \n'+
                     'Task kernel = /bin/sleep \n'+
                     'Task duration = X second(s) \n'+
                     'Number of trials per data point = %s'%trials)

ax.set_xlabel('Sleep duration (seconds)', fontsize=FONTSIZE)
ax.set_ylabel('Time (seconds)', fontsize=FONTSIZE)
ax.set_title(ax.get_title(), fontsize=FONTSIZE)

plt.legend(fontsize=FONTSIZE, loc='upper left')

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('../plots/entk_rp_overheads_sleep_supermic.pdf', dpi=100)
fig.savefig('../plots/entk_rp_overheads_sleep_supermic.png', dpi=100)
