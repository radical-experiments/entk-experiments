# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from radical.entk import Profiler
import radical.analytics as ra
import radical.utils as ru
import radical.pilot as rp
import numpy as np
from math import sqrt
import os

os.environ['RADICAL_PILOT_DBURL'] = 'mongodb://user:user@ds153652.mlab.com:53652/test_08_08'

# %matplotlib inline
# Out:
# /home/vivek/ves/ve_entk/lib/python2.7/site-packages/radical/utils/atfork/stdlib_fixer.py:63: UserWarning: logging module already imported before fixup.
#   warnings.warn('logging module already imported before fixup.')

# %%
# Constants
tasks_list = [16,32,64,128, 256, 512, 1024]
trials=3
data_loc = '../raw_data'
FONTSIZE=24

# %%
# Generate task uids

def get_task_uids(num_tasks):
    
    task_uids = []
    for t in range(num_tasks):
        task_uids.append('radical.entk.task.%04d'%t)

    return task_uids

# %%
df = pd.DataFrame(columns=['EnTK setup + teardown duration', 'EnTK execution duration', 'RP execution duration'])
df_err = pd.DataFrame(columns=['EnTK setup + teardown duration', 'EnTK execution duration', 'RP execution duration'])

for tasks in tasks_list:
    
    entk_setup_teardown_list = list()
    entk_task_overhead_list = list()
    rp_overhead_list = list()
    
    for t in range(1,trials+1):

        json_files = glob.glob('{0}/tasks-{1}-trial-{2}/*.json'.format(data_loc,tasks, t))
        json_file = json_files[0]
        json      = ru.read_json(json_file)
        sid       = os.path.basename(json_file)[:-5]

        session = ra.Session(sid, 'radical.pilot', src='{0}/tasks-{1}-trial-{2}/'.format(data_loc,tasks, t))
        units = session.filter(etype='unit', inplace=False)
        
        u1 = session.get(state=rp.UMGR_SCHEDULING_PENDING, etype='unit')
        start_rp = [u.states[rp.UMGR_SCHEDULING_PENDING]['time'] for u in u1]
        
        u2 = session.get(state=rp.DONE, etype='unit')
        stop_rp = [u.states[rp.DONE]['time'] for u in u2]
        
        min_rp = min(start_rp)
        max_rp = max(stop_rp)
    
        print 'RP duration using max and min: ', max_rp - min_rp

    
        p = Profiler(src = '{0}/tasks-{1}-trial-{2}/'.format(data_loc,tasks, t))
        
        task_uids = get_task_uids(16)
        
        entk_dur = p.duration(task_uids, states=['SCHEDULING', 'DONE'])
    
        rp_dur = units.duration([rp.UMGR_SCHEDULING_PENDING, rp.DONE])
        exec_dur = units.duration([rp.AGENT_EXECUTING, rp.AGENT_STAGING_OUTPUT_PENDING])
            
    
        # Time taken in appmanager to rreq function call
        entk_core_1 = p.duration('radical.entk.appmanager.0000', events=['create amgr obj', 'init rreq submission'])
        
        # Time taken to tear down appmanager
        entk_core_2 = p.duration('radical.entk.appmanager.0000', events=['start termination', 'termination done'])
    
        # Time taken to create resource manager obj
        entk_core_3 = p.duration('radical.entk.resource_manager.0000', events = ['create rmgr obj', 'rmgr obj created'])
    
        # Time taken to create and submit resource reservation
        entk_core_4 = p.duration('radical.entk.resource_manager.0000', events = ['creating rreq', 'rreq submitted'])
    
        # Time taken to deallocate resource reservation
        entk_core_5 = p.duration('radical.entk.resource_manager.0000', events = ['canceling resource allocation', 'resource allocation cancelled'])
    
        # Queue
        queue_time = p.duration('radical.entk.resource_manager.0000', events = ['rreq submitted', 'resource active'])
    
    
        entk_setup_teardown_dur = entk_core_1 + entk_core_2 + entk_core_3 
        entk_task_overhead = entk_dur - rp_dur
        rp_overhead = rp_dur - exec_dur
    
        #print 'EnTK setup + teardown overhead: ', entk_setup_teardown_dur
        #print 'EnTK task management duration: ', entk_dur
        print 'RP duration: ', rp_dur
        #print 'Execution duration: ', exec_dur
        #print 'Trial: ', t
        print '---------------------------------------'
        
        entk_setup_teardown_list.append(entk_setup_teardown_dur)
        entk_task_overhead_list.append(entk_dur)
        rp_overhead_list.append(rp_dur)
    
    df.loc[tasks] = [np.mean(entk_setup_teardown_list), 
                     np.mean(entk_task_overhead_list), 
                     np.mean(rp_overhead_list)]
    
    df_err.loc[tasks] = [np.std(entk_setup_teardown_list)/sqrt(trials), 
                     np.std(entk_task_overhead_list)/sqrt(trials), 
                     np.std(rp_overhead_list)/sqrt(trials)]
# Out:
# RP duration using max and min:  6.99300003052
# RP duration:  6.99300003052
# ---------------------------------------
# RP duration using max and min:  8.18519997597
# RP duration:  8.18519997597
# ---------------------------------------
# RP duration using max and min:  8.05780005455
# RP duration:  8.05780005455
# ---------------------------------------
# RP duration using max and min:  10.0209000111
# RP duration:  10.0209000111
# ---------------------------------------
# RP duration using max and min:  12.4568998814
# RP duration:  12.4568998814
# ---------------------------------------
# RP duration using max and min:  13.3905000687
# RP duration:  13.3905000687
# ---------------------------------------
# RP duration using max and min:  13.6448001862
# RP duration:  13.6448001862
# ---------------------------------------
# RP duration using max and min:  25.1372001171
# RP duration:  25.1372001171
# ---------------------------------------
# RP duration using max and min:  25.4722001553
# RP duration:  25.4722001553
# ---------------------------------------
# RP duration using max and min:  20.7053999901
# RP duration:  20.7053999901
# ---------------------------------------
# RP duration using max and min:  50.7300000191
# RP duration:  50.7300000191
# ---------------------------------------
# RP duration using max and min:  45.4340000153
# RP duration:  45.4340000153
# ---------------------------------------
# RP duration using max and min:  35.8048000336
# RP duration:  35.8048000336
# ---------------------------------------
# RP duration using max and min:  107.603600025
# RP duration:  107.603600025
# ---------------------------------------
# RP duration using max and min:  110.088799953
# RP duration:  110.088799953
# ---------------------------------------
# RP duration using max and min:  65.9463000298
# RP duration:  65.9463000298
# ---------------------------------------
# RP duration using max and min:  224.515799999
# RP duration:  224.515799999
# ---------------------------------------
# RP duration using max and min:  212.600300074
# RP duration:  212.600300074
# ---------------------------------------
# RP duration using max and min:  130.013799906
# RP duration:  130.013799906
# ---------------------------------------
# RP duration using max and min:  450.63470006
# RP duration:  450.63470006
# ---------------------------------------
# RP duration using max and min:  442.078700066
# RP duration:  442.078700066
# ---------------------------------------

# %%
ax = df.plot(kind='bar', 
             yerr=df_err,
             fontsize=FONTSIZE,
             title=  'Time taken by EnTK and RP to execute a workflow \n'+
                     'Workflow: 1 Pipeline, 1 Stage per Pipeline and X Tasks per Stage \n'+
                     'Resource: XSEDE.SuperMIC , Task kernel = /bin/sleep \n'+
                     'Task duration = 1 second(s) , Number of trials per data point = %s'%trials)

ax.set_xlabel('Number of Tasks', fontsize=FONTSIZE)
ax.set_ylabel('Time (seconds)', fontsize=FONTSIZE)
ax.set_title(ax.get_title(), fontsize=FONTSIZE)

plt.legend(fontsize=FONTSIZE, loc='upper left')

fig = plt.gcf()
fig.set_size_inches(24, 14)
fig.savefig('../plots/entk_rp_overheads_varying_tasks_sleep_kernel_supermic.pdf', dpi=100)
fig.savefig('../plots/entk_rp_overheads_varying_tasks_sleep_kernel_supermic.png', dpi=100)

# %%
duration_exec = units.duration([rp.AGENT_EXECUTING, rp.AGENT_STAGING_OUTPUT_PENDING])

before_exec = units.duration([rp.UMGR_SCHEDULING_PENDING, rp.AGENT_EXECUTING])
after_exec = units.duration([rp.AGENT_STAGING_OUTPUT_PENDING, rp.DONE])

total = units.duration([rp.UMGR_SCHEDULING_PENDING, rp.DONE])
print total
# Out:
# 130.013799906

# %%
print duration_exec, before_exec, after_exec
total_from_rp = duration_exec + before_exec + after_exec
print total_from_rp
# Out:
# 3.35220003128 5.23059988022 0.546700000763
# 9.12949991226
